# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import copy
import time
import sys
import math
import datetime
from math import radians, cos, sin, asin, sqrt
from matplotlib.colors import LogNorm
from io import StringIO
from sklearn import linear_model
#import tensorflow as tf
import seaborn as sns
from scipy import optimize
import math
#from scipy.optimize import curve_fit
plt.rcParams["font.sans-serif"]=["SimHei"] #用来正常显示中文标签
plt.rcParams["axes.unicode_minus"]=False #用来正常显示负号

# %%
pa=(np.load("3kmpa(bj).npy")).tolist()
pb=(np.load("3kmpb(bj).npy")).tolist()
ww=(np.load("3kmww(bj).npy")).tolist()
T_total2=(np.load("3kmT(bj).npy")).tolist()

# %%
dataframe=pd.DataFrame(columns=["Pa","Pb","d","T"])
dataframe["Pa"]=pd.Series(pa)
dataframe["Pb"]=pd.Series(pb)
dataframe["d"]=pd.Series(ww)
dataframe["T"]=pd.Series(T_total2)

# %%
dataframe1=dataframe[dataframe["Pa"]!=0]   
dr1=dataframe1[dataframe1["Pb"]!=0]

# %%
dr1
# Out:
#                  Pa             Pb         d    T
# 0      13136.122500   22092.779200  4.226313   16
# 1      75749.820770    6026.881808  4.227149   36
# 2       5065.468396    3703.199690  2.954342   17
# 3       4686.119923   12871.683030  4.226973   42
# 4      13522.620270    5994.581420  2.955482  644
# ...             ...            ...       ...  ...
# 2889  198855.752000  152698.037900  6.629270    7
# 2890   34872.508900   18565.362680  4.226583   30
# 2891  261943.648300  119216.781200  9.354196    3
# 2892  128691.068100  138185.728100  5.910053   12
# 2893   81277.496820    9940.547933  6.086030    4
#
# [2894 rows x 4 columns]

# %%
a=[]
b=[]
c=[]
r=[]
for _ in range(10000):
    np.random.seed()
    dt = dr1.sample(2000, replace=True)
    pa=(dt.Pa).tolist()
    pb=(dt.Pb).tolist()
    ww=(dt.d).tolist()
    T_total2=(dt["T"]).tolist()
    
    
    pa_=[]
    for i in range(0,len(pa)):
        z=pa[i]
        if (z!=0):
            z1=math.log10(z)
            pa_.append(z1)
        else:
            z1=0
            pa_.append(z1)
    pb_=[]
    for i in range(0,len(pb)):
        z=pb[i]
        if (z!=0):
            z1=math.log10(z)
            pb_.append(z1)
        else:
            z1=0
            pb_.append(z1)         
    ww_=[]
    for i in range(0,len(ww)):
        z=ww[i]
        if (z!=0):
            z1=math.log10(z)
            ww_.append(z1)
        else:
            z1=0
            ww_.append(z1)         
    logT=[]
    for i in range(0,len(T_total2)):
        z=T_total2[i]
        if (z!=0):
            z1=math.log10(z)
            logT.append(z1)
        else:
            z1=0
            logT.append(z1)        
    data=[]
    for i in range(0,len(pa_)):
        c=[]
        z1=pa_[i]
        z2=pb_[i]
        z3=ww_[i]
        #z4=logT[i]
        c.append(z1)
        c.append(z2)
        c.append(z3)
        #c.append(z4)
        data.append(c)        
            
    x=data
    y=logT        
    regr = linear_model.LinearRegression()
    regr.fit(x, y)
    con_a=regr.coef_
    con_b=regr.intercept_
    constant=10**con_b
    a.append(con_a[0])
    b.append(con_a[1])
    r.append(con_a[2])
    c.append(constant)

# %%
print(np.percentile(a, 2.5), np.percentile(a, 97.5))
print(np.percentile(b, 2.5), np.percentile(b, 97.5))
print(np.percentile(r, 2.5), np.percentile(r, 97.5))
print(np.percentile(c, 2.5), np.percentile(c, 97.5))
# Out:
# 0.5286092784507999 0.6761876466158829
# 0.4893422042784422 0.6356846253654143
# -4.017118171427192 -3.6710852929369433
# 0.10281080299243534 5.4427712929174685
