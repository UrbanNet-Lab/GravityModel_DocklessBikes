# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import copy
import time
import sys
import math
import datetime
from math import radians, cos, sin, asin, sqrt
from matplotlib.colors import LogNorm
from io import StringIO
from sklearn import linear_model
#import tensorflow as tf
import seaborn as sns
from scipy import optimize
import math
#from scipy.optimize import curve_fit
plt.rcParams["font.sans-serif"]=["SimHei"] #用来正常显示中文标签
plt.rcParams["axes.unicode_minus"]=False #用来正常显示负号

# %%
pa=(np.load("5kmpa(bj).npy")).tolist()
pb=(np.load("5kmpb(bj).npy")).tolist()
ww=(np.load("5kmww(bj).npy")).tolist()
T_total2=(np.load("5kmT(bj).npy")).tolist()

# %%
dataframe=pd.DataFrame(columns=["Pa","Pb","d","T"])
dataframe["Pa"]=pd.Series(pa)
dataframe["Pb"]=pd.Series(pb)
dataframe["d"]=pd.Series(ww)
dataframe["T"]=pd.Series(T_total2)

# %%
dataframe1=dataframe[dataframe["Pa"]!=0]   
dr1=dataframe1[dataframe1["Pb"]!=0]

# %%
dr1
# Out:
#                Pa            Pb          d     T
# 0     22342.50775   10013.98574   4.925483    30
# 1     17446.08486   31703.51642   4.926814     6
# 2     89171.24097   67000.29949   4.925437   500
# 3    688598.47140  840858.48260   7.044526   981
# 4    560376.27960  616152.07380   4.925504  9145
# ..            ...           ...        ...   ...
# 911  644370.90440  419189.77270  14.775671     2
# 912   39628.57682  558695.61390   9.849664     5
# 913  671675.46770  479329.17660  11.303058     2
# 914  483816.18920   76029.07522  15.209365     1
# 915   64677.21051   52082.55894   4.927852     1
#
# [916 rows x 4 columns]

# %%
a=[]
b=[]
c=[]
r=[]
for _ in range(10000):
    np.random.seed()
    dt = dr1.sample(800, replace=True)
    pa=(dt.Pa).tolist()
    pb=(dt.Pb).tolist()
    ww=(dt.d).tolist()
    T_total2=(dt["T"]).tolist()
    
    
    pa_=[]
    for i in range(0,len(pa)):
        z=pa[i]
        if (z!=0):
            z1=math.log10(z)
            pa_.append(z1)
        else:
            z1=0
            pa_.append(z1)
    pb_=[]
    for i in range(0,len(pb)):
        z=pb[i]
        if (z!=0):
            z1=math.log10(z)
            pb_.append(z1)
        else:
            z1=0
            pb_.append(z1)         
    ww_=[]
    for i in range(0,len(ww)):
        z=ww[i]
        if (z!=0):
            z1=math.log10(z)
            ww_.append(z1)
        else:
            z1=0
            ww_.append(z1)         
    logT=[]
    for i in range(0,len(T_total2)):
        z=T_total2[i]
        if (z!=0):
            z1=math.log10(z)
            logT.append(z1)
        else:
            z1=0
            logT.append(z1)        
    data=[]
    for i in range(0,len(pa_)):
        c=[]
        z1=pa_[i]
        z2=pb_[i]
        z3=ww_[i]
        #z4=logT[i]
        c.append(z1)
        c.append(z2)
        c.append(z3)
        #c.append(z4)
        data.append(c)        
            
    x=data
    y=logT        
    regr = linear_model.LinearRegression()
    regr.fit(x, y)
    con_a=regr.coef_
    con_b=regr.intercept_
    constant=10**con_b
    a.append(con_a[0])
    b.append(con_a[1])
    r.append(con_a[2])
    c.append(constant)

# %%
print(np.percentile(a, 2.5), np.percentile(a, 97.5))
print(np.percentile(b, 2.5), np.percentile(b, 97.5))
print(np.percentile(r, 2.5), np.percentile(r, 97.5))
print(np.percentile(c, 2.5), np.percentile(c, 97.5))
# Out:
# 0.6301186937132527 0.8458702919583487
# 0.5918216558423731 0.8038412717368713
# -5.60252764859896 -4.883641677930241
# 0.13355743447796553 5.918216145556278
