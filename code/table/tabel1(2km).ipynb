# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import copy
import time
import sys
import math
import datetime
from math import radians, cos, sin, asin, sqrt
from matplotlib.colors import LogNorm
from io import StringIO
from sklearn import linear_model
#import tensorflow as tf
import seaborn as sns
from scipy import optimize
import math
#from scipy.optimize import curve_fit
plt.rcParams["font.sans-serif"]=["SimHei"] #用来正常显示中文标签
plt.rcParams["axes.unicode_minus"]=False #用来正常显示负号

# %%
pa=(np.load("2kmpa(bj).npy")).tolist()
pb=(np.load("2kmpb(bj).npy")).tolist()
ww=(np.load("2kmww(bj).npy")).tolist()
T_total2=(np.load("2kmT(bj).npy")).tolist()

# %%
dataframe=pd.DataFrame(columns=["Pa","Pb","d","T"])
dataframe["Pa"]=pd.Series(pa)
dataframe["Pb"]=pd.Series(pb)
dataframe["d"]=pd.Series(ww)
dataframe["T"]=pd.Series(T_total2)

# %%
dataframe1=dataframe[dataframe["Pa"]!=0]   
dr1=dataframe1[dataframe1["Pb"]!=0]

# %%
dr1
# Out:
#                  Pa             Pb         d    T
# 0      14588.492770   29216.090380  2.818318  196
# 1       2761.375042    3814.971899  2.028949   12
# 2       3566.050913    4018.462147  2.817711    8
# 3       9523.344667   21389.341520  2.028397   52
# 4       7037.315018   15026.204980  2.028606  523
# ...             ...            ...       ...  ...
# 7195    1025.627589    1900.991908  5.909221    1
# 7196    2520.713302   10527.669060  6.085574    1
# 7197    6311.183992    1266.959673  2.836398    1
# 7198  109874.276800   89718.028150  8.113814    1
# 7199  129085.836600  187481.594700  6.382755    2
#
# [7200 rows x 4 columns]

# %%
a=[]
b=[]
c=[]
r=[]
for _ in range(10000):
    np.random.seed()
    dt = dr1.sample(7000, replace=True)
    pa=(dt.Pa).tolist()
    pb=(dt.Pb).tolist()
    ww=(dt.d).tolist()
    T_total2=(dt["T"]).tolist()
    
    
    pa_=[]
    for i in range(0,len(pa)):
        z=pa[i]
        if (z!=0):
            z1=math.log10(z)
            pa_.append(z1)
        else:
            z1=0
            pa_.append(z1)
    pb_=[]
    for i in range(0,len(pb)):
        z=pb[i]
        if (z!=0):
            z1=math.log10(z)
            pb_.append(z1)
        else:
            z1=0
            pb_.append(z1)         
    ww_=[]
    for i in range(0,len(ww)):
        z=ww[i]
        if (z!=0):
            z1=math.log10(z)
            ww_.append(z1)
        else:
            z1=0
            ww_.append(z1)         
    logT=[]
    for i in range(0,len(T_total2)):
        z=T_total2[i]
        if (z!=0):
            z1=math.log10(z)
            logT.append(z1)
        else:
            z1=0
            logT.append(z1)        
    data=[]
    for i in range(0,len(pa_)):
        c=[]
        z1=pa_[i]
        z2=pb_[i]
        z3=ww_[i]
        #z4=logT[i]
        c.append(z1)
        c.append(z2)
        c.append(z3)
        #c.append(z4)
        data.append(c)        
            
    x=data
    y=logT        
    regr = linear_model.LinearRegression()
    regr.fit(x, y)
    con_a=regr.coef_
    con_b=regr.intercept_
    constant=10**con_b
    a.append(con_a[0])
    b.append(con_a[1])
    r.append(con_a[2])
    c.append(constant)

# %%
print(np.percentile(a, 2.5), np.percentile(a, 97.5))
print(np.percentile(b, 2.5), np.percentile(b, 97.5))
print(np.percentile(r, 2.5), np.percentile(r, 97.5))
print(np.percentile(c, 2.5), np.percentile(c, 97.5))
# Out:
# 0.49953677456784784 0.580222479160996
# 0.4258165979863045 0.5046371930331035
# -3.0989140235986583 -2.9431039345498013
# 0.0849693338015163 4.94140879669027
