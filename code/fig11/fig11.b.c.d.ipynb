# %% [markdown]
# # 500m空间区域划分只有出流和只有入流区域空间分布及匹配
# 通过ArcGIS将空间区域划分为500mx500m的方形区域,然后对每个区域的单车出流和入流进行统计，得到的只有出流和入流的区域中心坐标集合，然后查看其空间分布，然后将只出区域和只进区域进行匹配，即在单车骑行记录中是否互为起始地和终点。

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import copy
import time
import sys
import math
import datetime
from math import radians, cos, sin, asin, sqrt
from matplotlib.colors import LogNorm
from io import StringIO
from sklearn import linear_model
#import tensorflow as tf
from scipy import optimize
#from scipy.optimize import curve_fit
plt.rcParams["font.sans-serif"]=["SimHei"] #用来正常显示中文标签
plt.rcParams["axes.unicode_minus"]=False #用来正常显示负号

# %%
from math import sin, asin, cos, radians, fabs, sqrt
EARTH_RADIUS=6371 
def hav(theta):
    s = sin(theta / 2)
    return s * s
def get_distance_hav(lat0, lng0, lat1, lng1):    #lat纬度
    lat0 = radians(lat0)
    lat1 = radians(lat1)
    lng0 = radians(lng0)
    lng1 = radians(lng1)
    dlng = fabs(lng0 - lng1)
    dlat = fabs(lat0 - lat1)
    h = hav(dlat) + cos(lat0) * cos(lat1) * hav(dlng)
    distance = 2 * EARTH_RADIUS * asin(sqrt(h))
    return distance

# %%
df=pd.read_csv('df.csv')   #筛选数据后的单车数据
df
# Out:
#          orderid   userid  bikeid  biketype            starttime  \
# 0        1893973   451147  210617         2  2017-05-14 22:16:50
# 1        4657992  1061133  465394         1  2017-05-14 22:16:52
# 2        2965085   549189  310572         1  2017-05-14 22:16:51
# 3        3936364   467449  403224         1  2017-05-14 22:16:50
# 4        5163705   917620  509044         1  2017-05-14 22:16:53
# ...          ...      ...     ...       ...                  ...
# 3094262   308143   683030   42881         1  2017-05-23 06:20:55
# 3094263  1886236   394183  209895         2  2017-05-23 06:20:57
# 3094264  2162814   878844  235870         2  2017-05-23 06:20:56
# 3094265  3702730   104540  380669         1  2017-05-23 06:20:56
# 3094266  2878326   466770  302424         2  2017-05-23 06:20:56
#
#         geohashed_start_loc geohashed_end_loc     start_x    start_y  \
# 0                   wx4snhx           wx4snhj  116.289597  40.103531
# ...

# %%
sid=(np.load("500m起始区域id(bj).npy")).tolist()   #每条单车骑行记录的区域id
sid1=pd.Series(sid)
eid=(np.load("500m终点区域id(bj).npy")).tolist()
eid1=pd.Series(eid)

# %%
df["sid"]=sid1   #起始id
df["eid"]=eid1   #终点id

# %%
s_eid=[]
for i in range(0,len(df)):
    c=[]
    a=df.iloc[i]["sid"]
    b=df.iloc[i]["eid"]
    c.append(a)
    c.append(b)
    s_eid.append(c)

# %%
for i in range(0,len(s_eid)):
    hr=s_eid[i]
    s_eid[i]=str(hr)

# %%
s_eid1=pd.Series(s_eid)
s_eid1
# Out:
# 0             [941, 9347]
# 1          [50459, 47949]
# 2           [4148, 58023]
# 3           [9126, 19416]
# 4           [6347, 23909]
#                 ...
# 3094262     [7521, 22824]
# 3094263    [10753, 54699]
# 3094264    [14429, 14445]
# 3094265     [3574, 11820]
# 3094266    [57346, 62927]
# Length: 3094267, dtype: object

# %%
df["s_eid"]=s_eid1

# %%
e_sid=[]
for i in range(0,len(df)):
    c=[]
    a=df.iloc[i]["sid"]
    b=df.iloc[i]["eid"]
    c.append(b)
    c.append(a)
    e_sid.append(c)

# %%
for i in range(0,len(e_sid)):
    hr=e_sid[i]
    e_sid[i]=str(hr)

# %%
e_sid1=pd.Series(e_sid)
e_sid1
# Out:
# 0             [9347, 941]
# 1          [47949, 50459]
# 2           [58023, 4148]
# 3           [19416, 9126]
# 4           [23909, 6347]
#                 ...
# 3094262     [22824, 7521]
# 3094263    [54699, 10753]
# 3094264    [14445, 14429]
# 3094265     [11820, 3574]
# 3094266    [62927, 57346]
# Length: 3094267, dtype: object

# %%
df["e_sid"]=e_sid1

# %%
df1_1=df[df["sid"]!=-1]

# %%
df1_2=df1_1[df1_1["eid"]!=-1]

# %%
df10=df1_2[df1_2["sid"]!=df1_2["eid"]]      #不在同一区域内的数据
df10
# Out:
#          orderid   userid  bikeid  biketype            starttime  \
# 0        1893973   451147  210617         2  2017-05-14 22:16:50
# 1        4657992  1061133  465394         1  2017-05-14 22:16:52
# 2        2965085   549189  310572         1  2017-05-14 22:16:51
# 3        3936364   467449  403224         1  2017-05-14 22:16:50
# 4        5163705   917620  509044         1  2017-05-14 22:16:53
# ...          ...      ...     ...       ...                  ...
# 3094262   308143   683030   42881         1  2017-05-23 06:20:55
# 3094263  1886236   394183  209895         2  2017-05-23 06:20:57
# 3094264  2162814   878844  235870         2  2017-05-23 06:20:56
# 3094265  3702730   104540  380669         1  2017-05-23 06:20:56
# 3094266  2878326   466770  302424         2  2017-05-23 06:20:56
#
#         geohashed_start_loc geohashed_end_loc     start_x    start_y  \
# 0                   wx4snhx           wx4snhj  116.289597  40.103531
# ...

# %%
loca1=(df1_2["sid"]).tolist()
loca2=(df1_2["eid"]).tolist()

# %%
local3=[]           #统计所有的区域
local3.extend(loca1)     
local3.extend(loca2)

# %%
local3=pd.Series(local3)

# %%
diff_loca=local3.value_counts()

# %%
diff_loca1=(diff_loca.index).tolist()  
diff_loca1    #所有不同区域
# Out:
# [64727,
#  57310,
#  64922,
#  56328,
#  181,
#  49515,
#  48636,
#  8396,
#  56642,
#  64795,
#  7114,
#  56606,
#  21429,
#  994,
#  51352,
#  16583,
#  9732,
#  61559,
#  64687,
#  52397,
#  827,
#  63477,
#  4708,
#  13192,
#  2696,
#  14782,
#  7160,
#  58506,
#  2267,
#  511,
#  28679,
#  59280,
#  15445,
#  27185,
#  16607,
#  50599,
#  11508,
#  54137,
#  9585,
#  2598,
#  8822,
#  194,
#  63198,
#  18246,
#  18737,
#  59120,
#  64037,
#  49825,
#  66582,
#  56712,
#  49754,
#  2271,
#  3424,
#  44692,
#  11885,
#  17402,
#  13171,
#  56707,
#  1042,
#  2955,
#  23427,
#  18964,
#  2964,
#  33563,
#  64879,
#  65518,
#  17509,
#  58831,
#  7324,
#  11177,
#  5468,
#  8089,
#  61562,
#  20090,
#  155,
#  55235,
#  44123,
#  36788,
#  7357,
#  25955,
#  65530,
#  1444,
#  22181,
#  4420,
#  5527,
#  59909,
#  11089,
#  2632,
#  20663,
#  62305,
#  21824,
#  8931,
#  10795,
#  22474,
#  5004,
#  63926,
#  6509,
#  50633,
#  597,
#  12787,
#  55829,
#  904,
#  7719,
#  5992,
# ...

# %%
df8_1=df1_2[df1_2["sid"]==df1_2["eid"]]      #在同一区域内的数据
df8_1
# Out:
#          orderid  userid  bikeid  biketype            starttime  \
# 6         495333  185893   67441         1  2017-05-14 22:16:53
# 17       1119812   72084  137713         2  2017-05-14 22:16:58
# 19       1745122  647684  196465         2  2017-05-14 22:17:00
# 64       1927777  753891  213795         2  2017-05-14 22:17:21
# 72        764025  852654  101207         1  2017-05-14 22:17:23
# ...          ...     ...     ...       ...                  ...
# 3094219  1675977  986520  189813         2  2017-05-23 06:20:39
# 3094232  3451860  120784  356447         1  2017-05-23 06:20:40
# 3094249  2821294  736434  297275         2  2017-05-23 06:20:44
# 3094253  3971890  376406  406493         1  2017-05-23 06:20:49
# 3094260   862349  135637  113390         1  2017-05-23 06:20:57
#
#         geohashed_start_loc geohashed_end_loc     start_x    start_y  \
# 6                   wx4emgw           wx4emgk  116.277237  39.966202
# ...

# %%
same_loca=df8_1["sid"].value_counts()
same_loca
# Out:
# 52397    1361
# 58506    1120
# 48636     875
# 64922     637
# 65518     582
#          ...
# 10065       1
# 20060       1
# 1621        1
# 53254       1
# 25011       1
# Name: sid, Length: 7422, dtype: int64

# %%
same_loca1=(same_loca.index).tolist()#有内环流量的区域
same_loca1
# Out:
# [52397,
#  58506,
#  48636,
#  64922,
#  65518,
#  11508,
#  9940,
#  904,
#  63198,
#  56642,
#  18246,
#  1042,
#  56328,
#  50599,
#  59909,
#  54137,
#  61562,
#  23413,
#  45766,
#  60807,
#  11782,
#  37984,
#  13192,
#  11457,
#  64037,
#  2696,
#  66582,
#  8931,
#  50638,
#  61430,
#  181,
#  21273,
#  2964,
#  57310,
#  3424,
#  8357,
#  65377,
#  22384,
#  65530,
#  11177,
#  994,
#  19359,
#  967,
#  40836,
#  56206,
#  58001,
#  64727,
#  6660,
#  63477,
#  1210,
#  4708,
#  27185,
#  597,
#  55829,
#  21644,
#  405,
#  24007,
#  21429,
#  11961,
#  1444,
#  58838,
#  56712,
#  16199,
#  61418,
#  511,
#  44692,
#  65156,
#  18344,
#  18319,
#  9732,
#  13171,
#  50459,
#  8396,
#  12062,
#  8706,
#  1649,
#  57354,
#  17635,
#  44521,
#  11128,
#  64879,
#  63019,
#  61981,
#  25955,
#  19378,
#  9341,
#  51352,
#  515,
#  12361,
#  54647,
#  62305,
#  3800,
#  53402,
#  61559,
#  18247,
#  14480,
#  17402,
#  20090,
#  25957,
#  2738,
#  11608,
#  59120,
#  5992,
# ...

# %%
unsame_loca=[]
for i in range(0,len(diff_loca1)):
    loci=diff_loca1[i]
    p=loci in same_loca1                   #判断是否是包含自流量的区域
    if(p==False):                          #不包含自流量区域
        unsame_loca.append(loci)

# %%
num_1=0                                             #空
num_2=0                                             #无出有进
num_3=0                                             #有出无进
num_4=0                                             #有出有进
lis1=[]
lis2=[]
lis3=[]
lis4=[]
for i in range(0,len(unsame_loca)):
    z=unsame_loca[i]
    dtf1=df1_2[df1_2["sid"]==z]    
    dtf1_1=dtf1[dtf1["sid"]!=dtf1["eid"]]
    l1=len(dtf1_1)
    
    dtf2=df1_2[df1_2["eid"]==z]
    dtf2_1=dtf2[dtf2["sid"]!=dtf2["eid"]]
    l2=len(dtf2_1)
    if(l1==0):
        if(l2==0):
            num_1=num_1+1      #数目
            lis1.append(z)
        else:
            num_2=num_2+1  
            lis2.append(z)
    else:
        if(l2==0):
            num_3=num_3+1      #数目
            lis3.append(z)
        else:
            num_4=num_4+1  
            lis4.append(z)

# %%
dfR2 = pd.read_csv("500popdata_bj.csv")      #包含区域人口数据
dfR2
# Out:
#        OBJECTID     Id  Shape_Length     Shape_Area           x          y  \
# 0             1      1    429.039265    5038.229607  117.287788  40.660110
# 1             2      2   2000.000000  250000.000000  117.219658  40.637150
# 2             3      3   2000.000000  250000.000000  116.406105  40.115814
# 3             4      4   2000.000000  250000.000000  116.558075  39.670311
# 4             5      5   2000.000000  250000.000000  116.881973  40.199058
# ...         ...    ...           ...            ...         ...        ...
# 66611     66612  66612   2000.000000  250000.000000  115.868393  39.889046
# 66612     66613  66613   2000.000000  250000.000000  115.907280  39.747780
# 66613     66614  66614   2000.000000  250000.000000  116.470535  39.798256
# 66614     66615  66615   2000.000000  250000.000000  115.858429  39.578114
# 66615     66616  66616   2000.000000  250000.000000  115.646408  39.760082
#
#        OBJECTID_1   Id_1  COUNT          AREA          SUM
# ...

# %%
x=(dfR2.x).tolist()
y=(dfR2.y).tolist()

# %%
i_d=(dfR2.Id).tolist()

# %%
xy=[]
for i in range(0,len(x)):
    l=[]
    a=x[i]
    b=y[i]
    l.append(a)
    l.append(b)
    xy.append(l)

# %%
b_= dict(zip(i_d,xy))

# %%
s=[]   #只出
e=[]
for temp in lis3:
    dr=df1_2[df1_2["sid"]==temp]
    x_y1=b_[temp]     #起始经纬
    s.append(x_y1)
    
    x_1=x_y1[0]   #经度
    y_1=x_y1[1]   #纬度
    
    Ti=len(dr)    
    e_id=(dr["eid"].value_counts().index).tolist()
    Tij=(dr["eid"].value_counts().values).tolist()
    
    Pij=[]    #归一化
    for i in range(0,len(Tij)):
        pij=Tij[i]/Ti
        Pij.append(pij)
    sub_x=0
    sub_y=0
    for i in range(0,len(e_id)):
        x_y2=b_[e_id[i]]
        x_2=x_y2[0]
        y_2=x_y2[1]
        xpart=(x_2-x_1)*Pij[i]
        ypart=(y_2-y_1)*Pij[i]
        sub_x+=xpart
        sub_y+=ypart
    x_11=x_1+sub_x    # 合成后的坐标
    y_11=y_1+sub_y
    xyl=[]
    xyl.append(x_11)
    xyl.append(y_11)
    e.append(xyl)

# %%
ssx=[]
ssy=[]
for i in range(0,len(s)):
    a=s[i]
    a1=a[0]
    a2=a[1]
    ssx.append(a1)
    ssy.append(a2)

# %%
#np.save('bj只出s',s)
#np.save('bj只出e',e)
#np.save('bj只出ssx',ssx)
#np.save('bj只出ssy',ssy)

# %%
#s=np.load('bj只出s.npy').tolist()
#e=np.load('bj只出e.npy').tolist()
#ssx=np.load('bj只出ssx.npy').tolist()
#ssy=np.load('bj只出ssy.npy').tolist()

# %%
df2=pd.read_csv('北京边界数据.csv')   #北京边界
bj_x=df2["x"].tolist()
bj_y=df2["y"].tolist()

# %%
fig= plt.figure(figsize=(10,9))      #只出区域
ax = fig.add_subplot(1,1,1) 

 
fig.set_facecolor('white')
plt.plot(bj_x,bj_y,color="black",linewidth="3")
#ax.set_xlim(120.8,122.1)
#ax.set_ylim(30.6,31.6)
#ax.scatter(cen_x,cen_y,color="black",s=15)
plt.yticks(fontproperties = 'Times New Roman')
plt.xticks(fontproperties = 'Times New Roman') 
ax.set_xlabel("longitude",size=22,family='Times New Roman')
ax.set_ylabel("latitude",size=22,family='Times New Roman')  

plt.tick_params(labelsize=20)
for i in range(0,len(s)):
    x=[]
    y=[]
    sxy=s[i]
    sx=sxy[0]
    sy=sxy[1]
    
    exy=e[i]
    ex=exy[0]
    ey=exy[1]
    x.append(sx)
    x.append(ex)
    y.append(sy)
    y.append(ey)
    
    plt.plot( x,y, color="red")
#ax.scatter(ssx,ssy,color="black",s=10)
#plt.savefig('500m只出流区域.pdf')

# %%
s=[]    #只进
e=[]
for temp in lis2:
    dr=df1_2[df1_2["eid"]==temp]
    x_y1=b_[temp]     
    s.append(x_y1)
    
    x_1=x_y1[0]   #经度
    y_1=x_y1[1]   #纬度
    
    Ti=len(dr)    
    s_id=(dr["sid"].value_counts().index).tolist()
    Tij=(dr["sid"].value_counts().values).tolist()
    
    Pij=[]    #归一化
    for i in range(0,len(Tij)):
        pij=Tij[i]/Ti
        Pij.append(pij)
    sub_x=0
    sub_y=0
    for i in range(0,len(s_id)):
        x_y2=b_[s_id[i]]
        x_2=x_y2[0]
        y_2=x_y2[1]
        xpart=(x_2-x_1)*Pij[i]
        ypart=(y_2-y_1)*Pij[i]
        sub_x+=xpart
        sub_y+=ypart
    x_11=x_1+sub_x    # 合成后的坐标
    y_11=y_1+sub_y
    xyl=[]
    xyl.append(x_11)
    xyl.append(y_11)
    e.append(xyl)

# %%
ssx=[]
ssy=[]
for i in range(0,len(s)):
    a=s[i]
    a1=a[0]
    a2=a[1]
    ssx.append(a1)
    ssy.append(a2)

# %%
#np.save('bj只进s',s)
#np.save('bj只进e',e)
#np.save('bj只进ssx',ssx)
#np.save('bj只进ssy',ssy)

# %%
fig= plt.figure(figsize=(10,9))      #只进区域
ax = fig.add_subplot(1,1,1) 

 
fig.set_facecolor('white')

plt.plot(bj_x,bj_y,color="black",linewidth="3")
#ax.scatter(cen_x,cen_y,color="black",s=15)
plt.yticks(fontproperties = 'Times New Roman')
plt.xticks(fontproperties = 'Times New Roman') 
ax.set_xlabel("longitude",size=22,family='Times New Roman')
ax.set_ylabel("latitude",size=22,family='Times New Roman')  

plt.tick_params(labelsize=20)
for i in range(0,len(s)):
    x=[]
    y=[]
    sxy=s[i]
    sx=sxy[0]
    sy=sxy[1]
    
    exy=e[i]
    ex=exy[0]
    ey=exy[1]
    x.append(sx)
    x.append(ex)
    y.append(sy)
    y.append(ey)
    
    plt.plot( x,y, color="red")
ax.scatter(ssx,ssy,color="black",s=10)
#plt.savefig('500m只入流区域.pdf')

# %%
jwd=[]       #只进
for i in range(0,len(lis2)):
    z=lis2[i]
    #p=z in b_b
    #if(p==True):
    a=b_[z]
    jwd.append(a)
    #else:
        #a=edict[z]
        #jwd.append(a)

# %%
xl=[]
yl=[]
for i in range(0,len(jwd)):
    z=jwd[i]
    xl.append(z[0])
    yl.append(z[1])

# %%
jwd1=[]
for i in range(0,len(lis3)):
    z=lis3[i]
    #p=z in sdict
    #if(p==True):
    a=b_[z]
    jwd1.append(a)
    #else:
        #a=edict[z]
        #jwd1.append(a)

# %%
xl1=[]
yl1=[]
for i in range(0,len(jwd1)):
    z=jwd1[i]
    xl1.append(z[0])
    yl1.append(z[1])

# %%
pix=[]
piy=[]
for i in range(0,len(lis2)):
    z=lis2[i]
    a=b_[z]
    x0=a[0]
    y0=a[1]
    a=df10[df10["eid"]==z]
    b=(a["sid"]).tolist()
    for j in range(0,len(b)):
        x=[]
        y=[]
        p=b[j] in lis3
        if(p==True): #在
            x.append(x0)
            y.append(y0)
            p1=b[j]
            p1_=b_[p1]
            x1=p1_[0]
            y1=p1_[1]
            x.append(x1)
            y.append(y1)
            pix.append(x)
            piy.append(y)

# %%
#np.save('bjkmpix',pix)
#np.save('bjkmpiy',piy)
#np.save('bjkmx1',xl)
#np.save('bjkmy1',yl)
#np.save('bjkmx11',xl1)
#np.save('bjkmy11',yl1)

# %%
#pix=np.load('bjkmpix.npy').tolist()
#piy=np.load('bjkmpiy.npy').tolist()
#xl=np.load('bjkmx1.npy').tolist()
#yl=np.load('bjkmy1.npy').tolist()
#xl1=np.load('bjkmx11.npy').tolist()
#yl1=np.load('bjkmy11.npy').tolist()

# %% [markdown]
# 区域匹配，红色连线为匹配区域中心坐标连线

# %%
fig= plt.figure(figsize=(10,9))      
ax = fig.add_subplot(1,1,1) 
 
fig.set_facecolor('white')
plt.plot(bj_x,bj_y,color="black",linewidth="3")



ax.set_xlabel("longitude",fontdict={'size'   : 22,"family":"Times New Roman"})#经度
ax.set_ylabel("latitude",fontdict={ 'size'   : 22,"family":"Times New Roman"})#纬度
#ax.scatter(cen_x,cen_y,color="black",s=30)
plt.yticks(fontproperties = 'Times New Roman')
plt.xticks(fontproperties = 'Times New Roman')
plt.tick_params(labelsize=16)
#ax.set_xlim(120.8,122.1)
#ax.set_ylim(30.6,31.6)
for i in range(0,len(pix)):
    x=pix[i]
    y=piy[i]  
    
    plt.plot(x,y,color="red",linewidth=1)
ax.scatter(xl,yl,alpha=1,color="black",marker="s",s=2,label="just_in")
ax.scatter(xl1,yl1,alpha=1,color="blue",marker="s",s=2,label="just_out")
plt.legend(loc="best",prop={'family':'Times New Roman','size':18})
#plt.savefig('500m出入流区域匹配.pdf')
